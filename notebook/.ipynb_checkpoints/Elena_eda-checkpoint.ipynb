# %%
import pandas as pd

# %%
df = pd.read_csv('data/clients.csv', index_col=0)

# %%
df
# Out:
#                             Полное наименование Компании  \
# №
# 1.0    Индивидуальный предприниматель Иванова Зоя Ник...
# NaN                                                  NaN
# 2.0    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# NaN                                                  NaN
# 3.0     Общество с ограниченной ответственностью "Хэйхэ"
# ...                                                  ...
# 786.0  Администрация муниципального образования "Нико...
# NaN                                                  NaN
# 787.0  Индивидуальный предприниматель Осепашвили Дмит...
# NaN                                                  NaN
# 788.0  Общество с ограниченной ответственностью "Груп...
#
#                            Краткое наименование Компании  ИНН Компании  \
# №
# 1.0    Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# NaN                                                  NaN           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 929 entries, 1.0 to 788.0
# Columns: 295 entries, Полное наименование Компании to Unnamed: 295
# dtypes: float64(40), object(255)
# memory usage: 2.1+ MB

# %%
df = df.dropna(how='all')

# %%
df.iloc[50:55]
# Out:
#                            Полное наименование Компании  \
# №
# 51.0  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВ...
# NaN   ПРЕДСТАВИТЕЛЬСТВО ФЕДЕРАЛЬНОГО ГОСУДАРСТВЕННОГ...
# NaN   ПРЕДСТАВИТЕЛЬСТВО ФЕДЕРАЛЬНОГО ГОСУДАРСТВЕННОГ...
# NaN   ПРЕДСТАВИТЕЛЬСТВО ФЕДЕРАЛЬНОГО ГОСУДАРСТВЕННОГ...
# 52.0  Общество с ограниченной ответственностью "Олен...
#
#      Краткое наименование Компании  ИНН Компании  ОГРН Компании  КПП Компании  \
# №
# 51.0         САМАРСКИЙ УНИВЕРСИТЕТ  6.316001e+09   1.026301e+12   631601001.0
# NaN                            NaN           NaN            NaN   280144001.0
# NaN                            NaN           NaN            NaN   632544001.0
# NaN                            NaN           NaN            NaN   632144001.0
# 52.0         ООО "Оленекские огни"  1.422002e+09   1.111433e+12   142201001.0
#
#       ОКПО Компании  ОКАТО Компании  ОКФС Компании  ОКТМО Компании  \
# №
# 51.0      2068410.0    3.640138e+10           12.0    3.670133e+10
# ...

# %%
df.reset_index()
# Out:
#          №                       Полное наименование Компании  \
# 0      1.0  Индивидуальный предприниматель Иванова Зоя Ник...
# 1      2.0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 2      3.0   Общество с ограниченной ответственностью "Хэйхэ"
# 3      4.0  Общество с ограниченной ответственностью "Школ...
# 4      5.0    Общество с ограниченной ответственностью "ЭЙГЭ"
# ..     ...                                                ...
# 924  784.0   Общество с ограниченной ответственностью "Мебко"
# 925  785.0  Общество с ограниченной ответственностью "Выбо...
# 926  786.0  Администрация муниципального образования "Нико...
# 927  787.0  Индивидуальный предприниматель Осепашвили Дмит...
# 928  788.0  Общество с ограниченной ответственностью "Груп...
#
#                          Краткое наименование Компании  ИНН Компании  \
# 0    Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 1                                     ООО МКК "СДЕЛКА"  1.435329e+09
# ...

# %%
df['ИНН Компании']
# Out:
# №
# 1.0      1.410002e+11
# 2.0      1.435329e+09
# 3.0      1.435122e+09
# 4.0      1.435222e+09
# 5.0      1.417008e+09
#              ...
# 784.0    1.435269e+09
# 785.0    4.704027e+09
# 786.0    1.417003e+09
# 787.0    1.435161e+11
# 788.0    1.435269e+09
# Name: ИНН Компании, Length: 929, dtype: float64

# %%
df.to_csv('data/clean_data.csv', encoding='utf-8-sig')

# %%
df.head(5)
# Out:
#                           Полное наименование Компании  \
# №
# 1.0  Индивидуальный предприниматель Иванова Зоя Ник...
# 2.0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3.0   Общество с ограниченной ответственностью "Хэйхэ"
# 4.0  Общество с ограниченной ответственностью "Школ...
# 5.0    Общество с ограниченной ответственностью "ЭЙГЭ"
#
#                          Краткое наименование Компании  ИНН Компании  \
# №
# 1.0  Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2.0                                   ООО МКК "СДЕЛКА"  1.435329e+09
# 3.0                                        ООО "Хэйхэ"  1.435122e+09
# 4.0                             ООО "Школьное питание"  1.435222e+09
# 5.0                                         ООО "ЭЙГЭ"  1.417008e+09
#
#      ОГРН Компании  КПП Компании  ОКПО Компании  ОКАТО Компании  \
# №
# 1.0   3.041410e+14           NaN    137459181.0    9.821850e+10
# 2.0   1.181447e+12   143501001.0     24900694.0    9.840100e+10
# ...

# %%
df.to_json('data.json', )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-640e25ec0fcf> in <module>
# ----> 1 df.to_json('data.json')
#
# ~/opt/anaconda3/envs/2020-10-illumidesk-env/lib/python3.8/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#    2291         indent = indent or 0
#    2292
# -> 2293         return json.to_json(
#    2294             path_or_buf=path_or_buf,
#    2295             obj=self,
#
# ~/opt/anaconda3/envs/2020-10-illumidesk-env/lib/python3.8/site-packages/pandas/io/json/_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#      73         raise NotImplementedError("'obj' should be a Series or a DataFrame")
#      74
# ...
